# %% [markdown]
# <a href="https://colab.research.google.com/github/RamyaSreeChippagiri/Chat_With_Your_DataFrame/blob/main/PandasAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q pandasai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.8/179.8 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 51.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 39.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 41.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.5/362.5 kB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 39.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.5/400.5 kB 16.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.9/332.9 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
from pandasai import SmartDataframe
from pandasai.llm.openai import OpenAI

# %%
data_dict = {
	"country": [
		"Delhi",
		"Mumbai",
		"Kolkata",
		"Chennai",
		"Jaipur",
		"Lucknow",
		"Pune",
		"Bengaluru",
		"Amritsar",
		"Agra",
		"Kola",
	],
	"annual tax collected": [
		19294482072,
		28916155672,
		24112550372,
		34358173362,
		17454337886,
		11812051350,
		16074023894,
		14909678554,
		43807565410,
		146318441864,
		np.nan,
	],
	"happiness_index": [9.94, 7.16, 6.35, 8.07, 6.98, 6.1, 4.23, 8.22, 6.87, 3.36, np.nan],
}

# %%
df = pd.DataFrame(data_dict)
df.head()
# Out:
#    country  annual tax collected  happiness_index
# 0    Delhi          1.929448e+10             9.94
# 1   Mumbai          2.891616e+10             7.16
# 2  Kolkata          2.411255e+10             6.35
# 3  Chennai          3.435817e+10             8.07
# 4   Jaipur          1.745434e+10             6.98

# %%
df.tail()
# Out:
#       country  annual tax collected  happiness_index
# 6        Pune          1.607402e+10             4.23
# 7   Bengaluru          1.490968e+10             8.22
# 8    Amritsar          4.380757e+10             6.87
# 9        Agra          1.463184e+11             3.36
# 10       Kola                   NaN              NaN

# %%
import os
os.environ["PANDASAI_API_KEY"] = "$2a$10$kvSn7ufuljAEYmmAIVMiFO1LkOqWZUhTFi7B2xasDknyumsB3cMmu"

# %%
llm = OpenAI(api_token=os.getenv("PANDASAI_API_KEY"))
pandas_ai = SmartDataframe(df)

# %%
response = pandas_ai.chat("What is the happiness index of Pune?")
print(response) #4.23
# Out:
# 4.23

# %%
response = pandas_ai.chat("What is the annual tax collected in Agra?")
print(response)
# Out:
# 146318441864.0
